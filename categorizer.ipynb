# %%
import ollama
import os

# %%
model = "llama3.2"

# %%
#paths to input and output files 
input_file = r"C:\Users\khair\Downloads\ollama\data\grocery.txt"
output_file = r"C:\Users\khair\Downloads\ollama\data\output_file.txt"

# %%
# Checking the existance of the input file 
if not os.path.exists(input_file):
    print( f"Input file '{input_file}' not found. ")	
    exit(1)

# %%
# Read the uncategorized grocery items from the input file 
with open(input_file, "r") as f :
    items = f.read().strip()

# Prepare the prompt for the model
prompt = f"""
You are an assistant that categorizes and sorts grocery items.

Here is a list of grocery items:

{items}

Please:

1. Categorize these items into appropriate categories such as Produce, Dairy, Meat, Bakery, Beverages, etc.
2. Sort the items alphabetically within each category.
3. Present the categorized list in a clear and organized manner, using bullet points or numbering.

"""

# %%
# Send the prompt and get the response
try:
    response = ollama.generate(model=model, prompt=prompt)
    generated_text = response.get("response", "")
    print("==== Categorized List: ===== \n")
    print(generated_text)

    # Write the categorized list to the output file
    with open(output_file, "w") as f:
        f.write(generated_text.strip())

    print(f"Categorized grocery list has been saved to '{output_file}'.")
except Exception as e:
    print("An error occurred:", str(e))
# Out:
# ==== Categorized List: =====
#
# Here is the categorized list of food items:
#
# **Beverages**
# • Beer (not listed)
# • Coffee (not listed)
# • Juice
# • Milk
# • Soda
# • Tea
# • Water
#
# (Note: Some items like whiskey and wine were not explicitly categorized as beverages, but are often classified under this category)
#
# **Bakery**
# • Bread
# • Cakes
# • Cookies
# • Muffins
# • Pastries
# • Pies
# • Rolls
# • Tortillas
# • Waffles
#
# **Dairy**
# • Cheese
# • Eggs
# • Milk
# • Sour cream
# • Yogurt
#
# **Meat**
# • Bacon
# • Beef
# • Chicken
# • Fish
# • Lamb
# • Pork
# • Rabbit
# • Sausage
# • Seafood (such as shrimp, salmon)
# • Turkey
#
# **Pantry**
# • Flour
# • Oil
# • Pasta
# • Rice
# • Semolina
# • Sugar
# • Soybeans
# • Tapioca
# • Tortilla chips
# • Vinegar
#
# **Produce**
# • Apples
# • Beans
# • Berries (such as strawberries, raspberries)
# • Broccoli
# • Carrots
# • Cucumbers
# • Figs
# • Herbs (such as parsley, thyme)
# • Kale
# • Lemons
# • Lettuce
# • Melons (such as watermelon, cantaloupe)
# • Mushrooms
# • Peaches
# • Peppers
# • Pineapple
# • Plums
# • Potatoes
# • Pumpkins
# • Spinach
# • Squash
# • Tomatoes
#
# **Snacks**
# • Chips
# • Crackers
# • Nuts (such as almonds, walnuts)
# • Popcorn
# • Pretzels
# • Seeds (such as sunflower seeds)
# • Trail mix
#
# **Sweets**
# • Candy
# • Ice cream
# • Pudding
# • Sorbet
# • Syrup
#
# **Tortilla-related items**
# • Taco shells
# • Tamales
# • Tortellini
# • Tortillas
# • Wrap tortillas
# Categorized grocery list has been saved to 'C:\Users\khair\Downloads\ollama\data\output_file.txt'.
